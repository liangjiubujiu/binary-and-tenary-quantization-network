# %%
% load_ext autoreload
% autoreload 2
# Plot configurations
% matplotlib inline
from __future__ import print_function
import tensorflow as tf
import numpy as np
from cifar_utils import load_data
from matplotlib import pyplot as plt
# Out:
# C:\Users\liang\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Load the raw CIFAR-10 data.
X_train, y_train = load_data(mode='train')

mask = np.arange(X_train.shape[0])
np.random.shuffle(mask)
X_train = X_train[mask]
y_train = y_train[mask]
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...

# %%
################## global contrast normalization ######################
lamda = 10
epsilon = 1e-7

#Because of memory issue, the pre-process of test data has to be after training data
mean_image = np.mean(X_train, axis=0)
X_train = X_train.astype(np.float32) - mean_image.astype(np.float32)
contrast = np.sqrt(lamda + np.mean(X_train**2,axis=0))
X_train = X_train / np.maximum(contrast, epsilon)

################## ZCA whitening #########################
temp = []
principal_components = []
for c in range(3):
    X = X_train[:,c*1024:(c+1)*1024]
    cov = np.dot(X.T, X) / (X.shape[0]-1)
    u, s, _ = np.linalg.svd(cov)
    principal_components.append( np.dot(np.dot(u, np.diag(1. / np.sqrt(s + 10e-7))), u.T) )

    # Apply ZCA whitening
    whitex = np.dot(X, principal_components[c])
    temp.append(whitex)

X_train = np.append(temp[0],temp[1],axis=1)
X_train = np.append(X_train,temp[2],axis=1)
X_train = X_train.reshape([50000,3,32,32]).transpose((0,2,3,1))

# %%
num_training = 45000
num_validation = 5000

X_val = X_train[-num_validation:, :]
y_val = y_train[-num_validation:]

X_train = X_train[:num_training, :]
y_train = y_train[:num_training]

X_test = []
y_test = []

X_test, y_test = load_data(mode='test')
X_test = X_test.astype(np.float32) - mean_image
contrast = np.sqrt(lamda + np.mean(X_test**2,axis=0))
X_test = X_test / np.maximum(contrast, epsilon)

for c in range(3): 
    X = X_test[:,c*1024:(c+1)*1024]
    whitex = np.dot(X, principal_components[c])
    temp[c] = whitex

X_test = np.append(temp[0],temp[1],axis=1)
X_test = np.append(X_test,temp[2],axis=1)
X_test = X_test.reshape([10000,3,32,32]).transpose((0,2,3,1))

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
#print('Test data shape: ', X_test.shape)
#print('Test labels shape: ', y_test.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Train data shape:  (45000, 32, 32, 3)
# Train labels shape:  (45000,)
# Validation data shape:  (5000, 32, 32, 3)
# Validation labels shape:  (5000,)

# %%
del temp
del whitex
del principal_components
del u
del s
del X

# %%
# No Regularizer
from binary import training
tf.reset_default_graph()
training(X_train, y_train, X_val, y_val, X_test, y_test,
                     is_binary = False, 
                     is_stochastic = False, 
                     conv_featmap = [128, 128, 256, 256, 512, 512],
                     fc_units = [1024, 1024],
                     conv_kernel_size = [3, 3, 3, 3, 3, 3],
         pooling_size = [2, 2, 2],
         lr_start = 0.001,
         lr_end = 0.0001, 
         epoch = 20,
         batch_size = 50,
         is_drop_out = False,
         verbose = True,
         pre_trained_model = None)
# Out:
# number of batches for training: 900
# epoch 1
# average train loss: 0.552013544374042 ,  average accuracy : 61.08444444444444%
# update learning rate:  [0.00089125097]
# validation accuracy : 65.53999999999999%
# * Best accuracy: 65.53999999999999%
# epoch 2
# average train loss: 0.458395932647917 ,  average accuracy : 78.05777777777777%
# update learning rate:  [0.0007943282]
# validation accuracy : 70.94%
# * Best accuracy: 70.94%
# epoch 3
# average train loss: 0.43521072917514375 ,  average accuracy : 83.25555555555556%
# update learning rate:  [0.0007079457]
# validation accuracy : 72.36%
# * Best accuracy: 72.36%
# epoch 4
# average train loss: 0.4198002501659923 ,  average accuracy : 87.16222222222223%
# update learning rate:  [0.00063095725]
# validation accuracy : 76.28%
# * Best accuracy: 76.28%
# epoch 5
# average train loss: 0.4059996331400341 ,  average accuracy : 90.64666666666666%
# update learning rate:  [0.00056234124]
# validation accuracy : 77.98%
# * Best accuracy: 77.98%
# epoch 6
# average train loss: 0.39730897890196903 ,  average accuracy : 92.82%
# update learning rate:  [0.00050118717]
# validation accuracy : 79.78%
# * Best accuracy: 79.78%
# epoch 7
# average train loss: 0.3907250710990694 ,  average accuracy : 94.72%
# update learning rate:  [0.00044668352]
# validation accuracy : 79.72%
# epoch 8
# average train loss: 0.38592792484495375 ,  average accuracy : 95.96444444444444%
# update learning rate:  [0.0003981071]
# validation accuracy : 74.86%
# epoch 9
# average train loss: 0.38281642668777044 ,  average accuracy : 96.87555555555555%
# update learning rate:  [0.00035481332]
# validation accuracy : 80.08%
# * Best accuracy: 80.08%
# epoch 10
# average train loss: 0.37998945193158257 ,  average accuracy : 97.6511111111111%
# update learning rate:  [0.0003162277]
# validation accuracy : 79.36%
# epoch 11
# average train loss: 0.3779063500298394 ,  average accuracy : 98.31333333333333%
# update learning rate:  [0.00028183823]
# validation accuracy : 79.58%
# epoch 12
# average train loss: 0.37679330160220464 ,  average accuracy : 98.67555555555556%
# update learning rate:  [0.00025118858]
# validation accuracy : 82.03999999999999%
# * Best accuracy: 82.03999999999999%
# epoch 13
# average train loss: 0.3760386275582843 ,  average accuracy : 98.87333333333333%
# update learning rate:  [0.00022387205]
# validation accuracy : 80.86%
# epoch 14
# average train loss: 0.37477658410867054 ,  average accuracy : 99.21111111111111%
# update learning rate:  [0.00019952617]
# validation accuracy : 82.72%
# * Best accuracy: 82.72%
# epoch 15
# average train loss: 0.37443396237161425 ,  average accuracy : 99.21333333333334%
# update learning rate:  [0.00017782788]
# validation accuracy : 82.48%
# epoch 16
# average train loss: 0.3750174468424585 ,  average accuracy : 99.22%
# update learning rate:  [0.00015848926]
# validation accuracy : 82.02%
# epoch 17
# average train loss: 0.37426935510502923 ,  average accuracy : 99.36222222222223%
# update learning rate:  [0.0001412537]
# validation accuracy : 83.06%
# * Best accuracy: 83.06%
# epoch 18
# average train loss: 0.37452535841200085 ,  average accuracy : 99.36666666666666%
# update learning rate:  [0.00012589249]
# validation accuracy : 82.88%
# epoch 19
# average train loss: 0.37416367630163827 ,  average accuracy : 99.44222222222223%
# update learning rate:  [0.00011220179]
# validation accuracy : 82.0%
# epoch 20
# average train loss: 0.37394934826427034 ,  average accuracy : 99.47555555555556%
# update learning rate:  [9.999995e-05]
# validation accuracy : 83.28%
# * Best accuracy: 83.28%
# test accuracy: 82.84%
# Traning ends. The best valid accuracy is 83.28%. Model named cifar10_1549233761.

# %%
# BinaryConnect det.
from binary import training
tf.reset_default_graph()
training(X_train, y_train, X_val, y_val, X_test, y_test,
         is_binary = True, 
         is_stochastic = False, 
         conv_featmap = [128, 128, 256, 256, 512, 512],
         fc_units = [1024, 1024],
         conv_kernel_size = [3, 3, 3, 3, 3, 3],
         pooling_size = [2, 2, 2],
         lr_start = 0.1,
         lr_end = 0.001, 
         epoch = 20,
         batch_size = 50,
         is_drop_out = False,
         verbose = True,
         pre_trained_model = None)
# Out:
# number of batches for training: 900
# epoch 1
# average train loss: 0.6522929443915685 ,  average accuracy : 44.34222222222222%
# update learning rate:  [0.07943282]
# validation accuracy : 51.86%
# * Best accuracy: 51.86%
# epoch 2
# average train loss: 0.5146370652980274 ,  average accuracy : 66.07777777777778%
# update learning rate:  [0.06309573]
# validation accuracy : 44.34%
# epoch 3
# average train loss: 0.49400254315800135 ,  average accuracy : 70.50222222222223%
# update learning rate:  [0.050118722]
# validation accuracy : 47.8%
# epoch 4
# average train loss: 0.4813077500462532 ,  average accuracy : 72.88222222222223%
# update learning rate:  [0.039810713]
# validation accuracy : 60.02%
# * Best accuracy: 60.02%
# epoch 5
# average train loss: 0.4675484471850925 ,  average accuracy : 76.15777777777778%
# update learning rate:  [0.03162277]
# validation accuracy : 63.42%
# * Best accuracy: 63.42%
# epoch 6
# average train loss: 0.4523362907767296 ,  average accuracy : 79.14222222222222%
# update learning rate:  [0.02511886]
# validation accuracy : 48.82%
# epoch 7
# average train loss: 0.4385202706853549 ,  average accuracy : 82.62666666666667%
# update learning rate:  [0.01995262]
# validation accuracy : 70.72%
# * Best accuracy: 70.72%
# epoch 8
# average train loss: 0.42734800729486677 ,  average accuracy : 85.39777777777778%
# update learning rate:  [0.015848929]
# validation accuracy : 76.12%
# * Best accuracy: 76.12%
# epoch 9
# average train loss: 0.4136089527606964 ,  average accuracy : 88.79777777777778%
# update learning rate:  [0.012589252]
# validation accuracy : 77.8%
# * Best accuracy: 77.8%
# epoch 10
# average train loss: 0.40254957497119903 ,  average accuracy : 91.65777777777778%
# update learning rate:  [0.009999998]
# validation accuracy : 77.38%
# epoch 11
# average train loss: 0.39317647924025856 ,  average accuracy : 94.09777777777778%
# update learning rate:  [0.00794328]
# validation accuracy : 78.52%
# * Best accuracy: 78.52%
# epoch 12
# average train loss: 0.3867279137174288 ,  average accuracy : 95.88888888888889%
# update learning rate:  [0.006309571]
# validation accuracy : 81.9%
# * Best accuracy: 81.9%
# epoch 13
# average train loss: 0.382163167198499 ,  average accuracy : 97.27111111111111%
# update learning rate:  [0.0050118705]
# validation accuracy : 81.98%
# * Best accuracy: 81.98%
# epoch 14
# average train loss: 0.3796495409475433 ,  average accuracy : 97.92888888888889%
# update learning rate:  [0.00398107]
# validation accuracy : 82.78%
# * Best accuracy: 82.78%
# epoch 15
# average train loss: 0.3775911474559042 ,  average accuracy : 98.54%
# update learning rate:  [0.0031622762]
# validation accuracy : 83.0%
# * Best accuracy: 83.0%
# epoch 16
# average train loss: 0.3760436286197768 ,  average accuracy : 98.97555555555556%
# update learning rate:  [0.0025118852]
# validation accuracy : 83.58%
# * Best accuracy: 83.58%
# epoch 17
# average train loss: 0.37524456123510996 ,  average accuracy : 99.22444444444444%
# update learning rate:  [0.0019952613]
# validation accuracy : 83.58%
# epoch 18
# average train loss: 0.37467987143331105 ,  average accuracy : 99.28666666666666%
# update learning rate:  [0.0015848924]
# validation accuracy : 83.56%
# epoch 19
# average train loss: 0.37415351145797304 ,  average accuracy : 99.43111111111111%
# update learning rate:  [0.0012589247]
# validation accuracy : 83.7%
# * Best accuracy: 83.7%
# epoch 20
# average train loss: 0.37421052200926674 ,  average accuracy : 99.43333333333334%
# update learning rate:  [0.0009999995]
# validation accuracy : 83.76%
# * Best accuracy: 83.76%
# test accuracy: 84.36%
# Traning ends. The best valid accuracy is 83.76%. Model named cifar10_1549234925.

# %%
# BinaryConnect stoch.
from binary import training
tf.reset_default_graph()
training(X_train, y_train, X_val, y_val, X_test, y_test,
         is_binary = True, 
         is_stochastic = True, 
         conv_featmap = [128, 128, 256, 256, 512, 512],
         fc_units = [1024, 1024],
         conv_kernel_size = [3, 3, 3, 3, 3, 3],
         pooling_size = [2, 2, 2],
         lr_start = 0.1,
         lr_end = 0.0001, 
         epoch = 50,
         batch_size = 50,
         is_drop_out = False,
         verbose = True,
         pre_trained_model = None)
# Out:
# number of batches for training: 900
# epoch 1
# average train loss: 0.7394289011425442 ,  average accuracy : 34.05111111111111%
# update learning rate:  [0.087096356]
# validation accuracy : 46.72%
# * Best accuracy: 46.72%
# epoch 2
# average train loss: 0.5385691745744812 ,  average accuracy : 62.315555555555555%
# update learning rate:  [0.07585775]
# validation accuracy : 51.14%
# * Best accuracy: 51.14%
# epoch 3
# average train loss: 0.5167757494913208 ,  average accuracy : 66.14444444444445%
# update learning rate:  [0.066069335]
# validation accuracy : 46.58%
# epoch 4
# average train loss: 0.5145139608449406 ,  average accuracy : 66.45111111111112%
# update learning rate:  [0.057543986]
# validation accuracy : 55.7%
# * Best accuracy: 55.7%
# epoch 5
# average train loss: 0.5089431831902927 ,  average accuracy : 67.69777777777779%
# update learning rate:  [0.050118715]
# validation accuracy : 47.32%
# epoch 6
# average train loss: 0.5042793378565047 ,  average accuracy : 68.69777777777777%
# update learning rate:  [0.043651573]
# validation accuracy : 61.56%
# * Best accuracy: 61.56%
# epoch 7
# average train loss: 0.49491536964972815 ,  average accuracy : 70.56666666666666%
# update learning rate:  [0.03801893]
# validation accuracy : 61.54%
# epoch 8
# average train loss: 0.48677918245395024 ,  average accuracy : 72.10888888888888%
# update learning rate:  [0.033113103]
# validation accuracy : 65.68%
# * Best accuracy: 65.68%
# epoch 9
# average train loss: 0.4794550141361025 ,  average accuracy : 73.63777777777779%
# update learning rate:  [0.028840307]
# validation accuracy : 50.02%
# epoch 10
# average train loss: 0.4720433271262381 ,  average accuracy : 75.34444444444445%
# update learning rate:  [0.025118858]
# validation accuracy : 56.2%
# epoch 11
# average train loss: 0.4631302309698529 ,  average accuracy : 76.99777777777777%
# update learning rate:  [0.02187761]
# validation accuracy : 60.24%
# epoch 12
# average train loss: 0.454481076962418 ,  average accuracy : 79.06888888888889%
# update learning rate:  [0.019054601]
# validation accuracy : 68.56%
# * Best accuracy: 68.56%
# epoch 13
# average train loss: 0.447178234954675 ,  average accuracy : 80.53999999999999%
# update learning rate:  [0.016595863]
# validation accuracy : 71.44%
# * Best accuracy: 71.44%
# epoch 14
# average train loss: 0.44205987678633796 ,  average accuracy : 81.74888888888889%
# update learning rate:  [0.014454392]
# validation accuracy : 74.53999999999999%
# * Best accuracy: 74.53999999999999%
# epoch 15
# average train loss: 0.4336836258570353 ,  average accuracy : 83.74888888888889%
# update learning rate:  [0.012589249]
# validation accuracy : 74.44%
# epoch 16
# average train loss: 0.4275263712472386 ,  average accuracy : 85.39111111111112%
# update learning rate:  [0.010964777]
# validation accuracy : 78.08%
# * Best accuracy: 78.08%
# epoch 17
# average train loss: 0.4209006524748272 ,  average accuracy : 87.00888888888889%
# update learning rate:  [0.009549921]
# validation accuracy : 73.2%
# epoch 18
# average train loss: 0.4154386004143291 ,  average accuracy : 88.2911111111111%
# update learning rate:  [0.0083176335]
# validation accuracy : 80.02%
# * Best accuracy: 80.02%
# epoch 19
# average train loss: 0.4104670276575618 ,  average accuracy : 89.70444444444445%
# update learning rate:  [0.007244356]
# validation accuracy : 80.46000000000001%
# * Best accuracy: 80.46000000000001%
# epoch 20
# average train loss: 0.40610881590180925 ,  average accuracy : 90.82222222222222%
# update learning rate:  [0.0063095703]
# validation accuracy : 81.22%
# * Best accuracy: 81.22%
# epoch 21
# average train loss: 0.40191501528024676 ,  average accuracy : 92.05555555555556%
# update learning rate:  [0.0054954058]
# validation accuracy : 81.34%
# * Best accuracy: 81.34%
# epoch 22
# average train loss: 0.3985274287727144 ,  average accuracy : 93.06666666666666%
# update learning rate:  [0.004786298]
# validation accuracy : 81.7%
# * Best accuracy: 81.7%
# epoch 23
# average train loss: 0.39666811522510315 ,  average accuracy : 93.44%
# update learning rate:  [0.004168691]
# validation accuracy : 80.22%
# epoch 24
# average train loss: 0.39368080874284106 ,  average accuracy : 94.39555555555556%
# update learning rate:  [0.003630778]
# validation accuracy : 82.46000000000001%
# * Best accuracy: 82.46000000000001%
# epoch 25
# average train loss: 0.392147195438544 ,  average accuracy : 94.73777777777778%
# update learning rate:  [0.0031622755]
# validation accuracy : 82.32%
# epoch 26
# average train loss: 0.3899180163608657 ,  average accuracy : 95.49333333333334%
# update learning rate:  [0.0027542268]
# validation accuracy : 82.32%
# epoch 27
# average train loss: 0.38779426376024884 ,  average accuracy : 96.05333333333333%
# update learning rate:  [0.0023988313]
# validation accuracy : 82.84%
# * Best accuracy: 82.84%
# epoch 28
# average train loss: 0.38637958380911086 ,  average accuracy : 96.41333333333333%
# update learning rate:  [0.0020892946]
# validation accuracy : 83.4%
# * Best accuracy: 83.4%
# epoch 29
# average train loss: 0.38549117743968964 ,  average accuracy : 96.70666666666666%
# update learning rate:  [0.0018196995]
# validation accuracy : 83.46000000000001%
# * Best accuracy: 83.46000000000001%
# epoch 30
# average train loss: 0.38519984129402374 ,  average accuracy : 96.76666666666667%
# update learning rate:  [0.001584892]
# validation accuracy : 83.86%
# * Best accuracy: 83.86%
# epoch 31
# average train loss: 0.3839319406615363 ,  average accuracy : 97.1288888888889%
# update learning rate:  [0.0013803833]
# validation accuracy : 83.8%
# epoch 32
# average train loss: 0.3827345456017388 ,  average accuracy : 97.37555555555555%
# update learning rate:  [0.0012022635]
# validation accuracy : 84.18%
# * Best accuracy: 84.18%
# epoch 33
# average train loss: 0.3824535995059543 ,  average accuracy : 97.5911111111111%
# update learning rate:  [0.0010471278]
# validation accuracy : 84.02%
# epoch 34
# average train loss: 0.38165179183085757 ,  average accuracy : 97.72666666666666%
# update learning rate:  [0.00091201015]
# validation accuracy : 83.36%
# epoch 35
# average train loss: 0.38177588327063455 ,  average accuracy : 97.74666666666667%
# update learning rate:  [0.00079432764]
# validation accuracy : 84.22%
# * Best accuracy: 84.22%
# epoch 36
# average train loss: 0.38185573326216804 ,  average accuracy : 97.83111111111111%
# update learning rate:  [0.0006918305]
# validation accuracy : 84.16%
# epoch 37
# average train loss: 0.38108242217037414 ,  average accuracy : 98.04222222222222%
# update learning rate:  [0.0006025591]
# validation accuracy : 83.92%
# epoch 38
# average train loss: 0.38122901257541447 ,  average accuracy : 97.92444444444445%
# update learning rate:  [0.000524807]
# validation accuracy : 84.16%
# epoch 39
# average train loss: 0.3804508247640398 ,  average accuracy : 98.15777777777778%
# update learning rate:  [0.0004570878]
# validation accuracy : 84.28%
# * Best accuracy: 84.28%
# epoch 40
# average train loss: 0.3804027824269401 ,  average accuracy : 98.1511111111111%
# update learning rate:  [0.00039810681]
# validation accuracy : 84.22%
# epoch 41
# average train loss: 0.3806160027782122 ,  average accuracy : 98.02444444444444%
# update learning rate:  [0.00034673655]
# validation accuracy : 84.36%
# * Best accuracy: 84.36%
# epoch 42
# average train loss: 0.3796546861860487 ,  average accuracy : 98.32%
# update learning rate:  [0.0003019949]
# validation accuracy : 84.42%
# * Best accuracy: 84.42%
# epoch 43
# average train loss: 0.37979358000887764 ,  average accuracy : 98.24222222222222%
# update learning rate:  [0.00026302657]
# validation accuracy : 84.64%
# * Best accuracy: 84.64%
# epoch 44
# average train loss: 0.38040955132908294 ,  average accuracy : 98.17111111111112%
# update learning rate:  [0.00022908655]
# validation accuracy : 84.62%
# epoch 45
# average train loss: 0.3799919549624125 ,  average accuracy : 98.24222222222222%
# update learning rate:  [0.00019952604]
# validation accuracy : 84.48%
# epoch 46
# average train loss: 0.3799339230855306 ,  average accuracy : 98.32%
# update learning rate:  [0.00017377992]
# validation accuracy : 84.48%
# epoch 47
# average train loss: 0.3794797126783265 ,  average accuracy : 98.46%
# update learning rate:  [0.00015135598]
# validation accuracy : 84.56%
# epoch 48
# average train loss: 0.3797763231727812 ,  average accuracy : 98.36444444444444%
# update learning rate:  [0.00013182555]
# validation accuracy : 84.8%
# * Best accuracy: 84.8%
# epoch 49
# average train loss: 0.3796365750498242 ,  average accuracy : 98.28444444444445%
# update learning rate:  [0.00011481525]
# validation accuracy : 84.6%
# epoch 50
# average train loss: 0.37955375307136113 ,  average accuracy : 98.29333333333334%
# update learning rate:  [9.99999e-05]
# validation accuracy : 84.53999999999999%
# test accuracy: 84.83%
# Traning ends. The best valid accuracy is 84.8%. Model named cifar10_1549236134.
